# %% [markdown]
# # Analyzing data from Medcon
# ## Time of effect of covid vaccine
#
# #### Created by Deborah Won
# #### For BME 2810

# %% [markdown]
# A pharmaceutical company named Medicon produced a Covid-19 vaccine, and our job is to describe its effectiveness. Medicon has collected data on one batch of the dose - namely, the "time of effect", which is the duration, measured in hours, from the time at which the vaccine is administered until the body has absorbed it and until antibodies are produced. Essentially, time of effect is defined as the number of hours it takes for the vaccine to manifest a preventative effect against Covid-19.

# %%
# there is no output but cell imports code within library called pandas
# nickname pd
import pandas as pd

# %%
import numpy as np

# %%
# reads csv file from path specified
# stores it as a dataframe
data = pd.read_csv("/Users/esmeraldaamado/Downloads/doses.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
len(data)
# Out:
# 50

# %%
data.shape
# Out:
# (50, 2)

# %%
# prints top 10 observations 
data.head(n=10)
# Out:
#    drug_serial_number  time_of_effect
# 0                 672             5.8
# 1                 895            17.3
# 2                 518            16.7
# 3                 448            13.1
# 4                 402            13.6
# 5                 990             7.6
# 6                 744            14.0
# 7                 565             7.1
# 8                 145            13.2
# 9                 909            15.5

# %%
# prints out the names of the columns in our dataframe
data.columns
# Out:
# Index(['drug_serial_number', 'time_of_effect'], dtype='object')

# %%
# extract column labeled "time_of_effect" abd store in a variable called tEffect
tEffect = data["time_of_effect"]

# prints what type of variable is tEffect
print(type(tEffect))

# prints out the shape, i.e, the size of each dimension
print(tEffect.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (50,)

# %%
# outputs the mean of the data in tEffect
# applying the mean method to tEffect
tEffect.mean()
# Out:
# np.float64(13.442)

# %%
# using library numpy to create an array from the column "time_of_effect"
teff = np.array(data["time_of_effect"])
print(type(teff))
teff.mean()
# Out:
# <class 'numpy.ndarray'>
# np.float64(13.442)

# %%
# gets the mean function from the np library
# applies it to the variable tEffect
muT = np.mean(tEffect)

# %%
print(muT)
# Out:
# 13.442

# %%
sigmaT = np.std(tEffect)
print(sigmaT)
# Out:
# 4.697833117512796

# %%
tEffect.std
# Out:
# 4.7455280775371955
