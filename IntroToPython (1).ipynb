# %% [markdown]
# # Introduction to Jupyter Notebooks
# ## Learning basic python commands and formatting Jupyter Notebooks
# ### For BME 2810
# ### By Deborah Won

# %%
# hashtag sympbol in a code block means this line is a comment
# numerical variables
age = 34

height = 63   # in inches

weight = 120 # in lbs

# %%
age
height
# Out:
# 63

# %%
print(age)
print(height)
# Out:
# 34
# 63

# %%
# string variables
name = 'Debbie'

# %%
name
# Out:
# 'Debbie'

# %%
heightStr = '63'
heightStr
# Out:
# '63'

# %%
print(height*2)
# Out:
# 126

# %%
print(heightStr*2)
# Out:
# 6363

# %%
print(type(height))
print(type(heightStr))
# Out:
# <class 'int'>
# <class 'str'>
